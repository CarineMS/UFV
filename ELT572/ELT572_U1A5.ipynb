# %% [markdown]
# <a href="https://colab.research.google.com/github/CarineMS/UFV/blob/main/ELT572_U1A5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Caderno de Exercícios Python
#
#
# #### Capítulo 05 - Classes
# #### Disciplina: Linguagens de Programação para Inteligência Artificial
#
# **Aluna:** Carine Madeira Soares
# **Instituição:** Universidade Federal de Viçosa

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# As classes dessas aulas foram desenvolvidas localmente em documentos .py
#
# Os códigos estaram no GitHub na mesma pasta que os cardernos de exercícios.
#
#
# Afim de tornar exemplificado a saída dos códigos incluirei aqui no Colab os prints no momento em que chamo a função, passo os parâmetros e a saída da função.

# %% [markdown]
# ## Classe Dog

# %% [markdown]
# ![output_dog.png](data:image/png;base64,...)

# %% [markdown]
# ## Classe Car

# %% [markdown]
# ![output_car.png](data:image/png;base64,...)
